# %% [markdown]
# # Analysis of running simulation
# ### update 16.03.2020
#
# ## RMSD
#
# definition by core:
#
# :15-41,130-158,161-182,185-214,219-235,237-267,337-358,367-386,394-411,422-448,453-481,487-498@C,CA,N,O
#
# and to reference of the 1st frame POPC system
#
# ### POPC
#
# ![oat1_popc_rmsd_by_core_1.png](attachment:oat1_popc_rmsd_by_core_1.png)
#
# ![oat1_popc_rmsd_core_tmh12_ref_1.png](attachment:oat1_popc_rmsd_core_tmh12_ref_1.png)
#
# ### POPC:POPE (3:1)
#
# ![oat1_2popc_pope1_chol1_rmsd_by_core_1.png](attachment:oat1_2popc_pope1_chol1_rmsd_by_core_1.png)
#
# ![oat1_2popc_pope1_chol1_rmsd_core-tmh12-ref_1.png](attachment:oat1_2popc_pope1_chol1_rmsd_core-tmh12-ref_1.png)
#
# ### POPC:Chol (3:1)
#
# ![oat1_3popc_1chol_rmsd_core-all.png](attachment:oat1_3popc_1chol_rmsd_core-all.png)
# ![oat1_3popc_1chol_rmsd_by_core_1.png](attachment:oat1_3popc_1chol_rmsd_by_core_1.png)
# ![oat1_3popc_1chol_rmsd_core-tmh12-ref_1.png](attachment:oat1_3popc_1chol_rmsd_core-tmh12-ref_1.png)
#
# ### POPC:POPE:Chol (2:1:1)
#
# ![oat1_2popc_pope1_chol1_rmsd_by_core_1.png](attachment:oat1_2popc_pope1_chol1_rmsd_by_core_1.png)
# ![oat1_2popc_pope1_chol1_rmsd_core-tmh12-ref_1.png](attachment:oat1_2popc_pope1_chol1_rmsd_core-tmh12-ref_1.png)
